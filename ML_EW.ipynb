# %%
# Import Dependencies 
import pandas as pd

# %%
# Get Data
data_path = "Output/movies_cleaned2.csv"
df = pd.read_csv(data_path)
# Out:
#        id                            original_title  release_year  \
# 0   19995                                    Avatar          2009
# 1     285  Pirates of the Caribbean: At World's End          2007
# 2  206647                                   Spectre          2015
# 3   49026                     The Dark Knight Rises          2012
# 4   49529                               John Carter          2012
#
#                                       genre  \
# 0  Action,Adventure,Fantasy,Science Fiction
# 1                  Adventure,Fantasy,Action
# 2                    Action,Adventure,Crime
# 3               Action,Crime,Drama,Thriller
# 4          Action,Adventure,Science Fiction
#
#                                             overview  runtime  vote_average  \
# 0  In the 22nd century, a paraplegic Marine is di...    162.0           7.2
# 1  Captain Barbossa, long believed to be dead, ha...    169.0           6.9
# 2  A cryptic message from Bond’s past sends him o...    148.0           6.3
# 3  Following the death of District Attorney Harve...    165.0           7.6
# 4  John Carter is a war-weary, former military ca...    132.0           6.1
#
#                                           keywording original_language  \
# 0  culture clash,future,space war,space colony,so...                en
# 1  ocean,drug abuse,exotic island,east india trad...                en
# 2  spy,based on novel,secret agent,sequel,mi6,bri...                en
# 3  dc comics,crime fighter,terrorist,secret ident...                en
# 4  based on novel,mars,medallion,space travel,pri...                en
#
#                                       prod_companies  \
# 0  Ingenious Film Partners,Twentieth Century Fox ...
# 1  Walt Disney Pictures,Jerry Bruckheimer Films,S...
# 2                       Columbia Pictures,Danjaq,B24
# 3  Legendary Pictures,Warner Bros.,DC Entertainme...
# 4                               Walt Disney Pictures
#
#                             prod_countries release_date     budget  \
# 0  United States of America,United Kingdom   2009-12-10  237000000
# 1                 United States of America   2007-05-19  300000000
# 2  United Kingdom,United States of America   2015-10-26  245000000
# 3                 United States of America   2012-07-16  250000000
# 4                 United States of America   2012-03-07  260000000
#
#       revenue  popularity                           languages_spoken  \
# 0  2787965087  150.437577                            English,Español
# 1   961000000  139.082615                                    English
# 2   880674609  107.376788  Français,English,Español,Italiano,Deutsch
# 3  1084939099  112.312950                                    English
# 4   284139100   43.926995                                    English
#
#                                              casting
# 0  Sam Worthington,Zoe Saldana,Sigourney Weaver,S...
# 1  Johnny Depp,Orlando Bloom,Keira Knightley,Stel...
# 2  Daniel Craig,Christoph Waltz,Léa Seydoux,Ralph...
# 3  Christian Bale,Michael Caine,Gary Oldman,Anne ...
# 4  Taylor Kitsch,Lynn Collins,Samantha Morton,Wil...

# %%
# Get Survey Data
sd_df = pd.read_csv('Resources/Survey_Mood_MovieGenre.csv')
sd_df.head()
# Out:
#    ID   Age      Mood                 Movie_1                      Movie_2  \
# 0   1  18 +     Happy       Fifty first dates  What they do in the shadows
# 1   2  18 +  Inspired             I am legend                      Aladdin
# 2   3  18 +  Thrilled  Straight outta Compton           rabbit proof fence
# 3   4  18 +     Happy            King Richard                   Rocket man
# 4   5  18 +     Happy        2 fast 2 furious                hacksaw ridge
#
#                     Movie_3              Movie_4        Movie_5 Movie_1_genre  \
# 0                    Avatar           About time     James Bond        Comedy
# 1             A quiet place          World War Z           Coco         Drama
# 2              hunger games  never stop stopping      gone girl         Drama
# 3             the kings man               Xanadu  the bodyguard       History
# 4  pirates of the Caribbean        the big short   white chicks        Action
#
#   Movie_2_genre Movie_3_genre Movie_4_genre Movie_5_genre
# 0        Comedy        Action        Comedy        Action
# 1     Animation       Fantasy        Action     Animation
# 2         Drama       Fantasy        Comedy       Mystery
# 3       History        Action       Fantasy      Thriller
# 4           War      Thriller        Comedy        Comedy

# %%
# Function to Collate all the data based on column name 
def merge_profile(df, movie, genre):
    movie_col = "Movie_" + movie
    genre_col = "Movie_" + genre + '_genre'


    # pick the columns from the dataframe 
    df_merge = df[['ID','Mood','Age',movie_col,genre_col]]

    df_merge = df_merge.rename(columns = {movie_col:'title',genre_col:'genre'})

    return df_merge
# Out:
#    ID      Mood   Age                   title    genre
# 0   1     Happy  18 +       Fifty first dates   Comedy
# 1   2  Inspired  18 +             I am legend    Drama
# 2   3  Thrilled  18 +  Straight outta Compton    Drama
# 3   4     Happy  18 +            King Richard  History
# 4   5     Happy  18 +        2 fast 2 furious   Action

# %%
# Iterate through survery data and merge 

# Initiate empty list to store 
data_lst = []

# Iterate through 5 times as we know we have a static number of columns
for x in range(4):
    # Ensure list is clear, no residual data
    data_lst.clear()

    # Calling function and filling up list
    df_ = merge_profile(sd_df,str(x+1),str(x+1))
    data_lst.append(df_.values.tolist())
# Out:
# [1, 'Happy', '18 +', 'About time', 'Comedy']

# %%
# re-instate dataframe 
merged_df = pd.DataFrame(data_lst[0],columns = ['id','mood','age','title','genre'])
# Out:
#     id       mood   age                title    genre
# 0    1      Happy  18 +           About time   Comedy
# 1    2   Inspired  18 +          World War Z   Action
# 2    3   Thrilled  18 +  never stop stopping   Comedy
# 3    4      Happy  18 +               Xanadu  Fantasy
# 4    5      Happy  18 +        the big short   Comedy
# ..  ..        ...   ...                  ...      ...
# 93  94  Emotional  18 +          remember me    Drama
# 94  95  Emotional  18 +          Jojo rabbit      War
# 95  96  Emotional  18 +          remember me    Drama
# 96  97  Emotional  18 +           about time   Comedy
# 97  98   Romantic  18 +        cool runnings   Comedy
#
# [98 rows x 5 columns]
